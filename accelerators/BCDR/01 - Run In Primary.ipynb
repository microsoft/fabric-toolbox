# %% [markdown]
# #### Introduction
#
# This set of notebooks (01 - Run in Primary and 02 - Run in DR) demonstrates an automated end-to-end BCDR process to recover supported (Git) items, lakehouses, warehouses and associated data.

# %% [markdown]
# ##### Prerequisites
# Please read the disaster recovery guidance found in <a href="https://learn.microsoft.com/en-us/fabric/security/experience-specific-guidance">the documentation</a> to obtain a general understanding of how to recover lakehouse and warehouse data.
# When the OneLake DR setting has been enabled at capacity level, lakehouse and warehouse data will be geo-replicated to the secondary (paired) region. As mentioned in the documentation, this data may be inaccessible through the normal Fabric UI experience, therefore the data will need to be recovered into a corresponding (new) workspace in the DR region using the storage endpoints (abfs paths) as depicted in the image below.
# <div>
# <img src="https://github.com/hurtn/images/blob/main/reco_from_docs.png?raw=true" width="800"/>
# </div>
#
# To use this notebook ensure this runs in a new workspace (Reco1) attached to a new lakehouse (LH_BCDR) and ensure DR is enabled for the assocated capacity (C1).
#
# <div>
# <img src="https://github.com/hurtn/images/blob/main/before_recovery.png?raw=true" width="800"/>
# </div>

# %% [markdown]
# ###### About this notebook
#
# This part of the BCDR process collects metadata about your Fabric environment, such as information about your  capacities, workspaces, their assocated Git connections (if connected to Git) and Fabric items. This metadata is used in second notebook "02 - Run in DR" during the recovery process.

# %% [markdown]
# ##### Imports and Utility Functions
# Ensure the cell below is runs successfully to include the supporting functions

# %%
# %run workspaceutils
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 5, Finished, Available, Finished, True)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.14.0-py3-none-any.whl.metadata (29 kB)
# Collecting semantic-link-sempy>=0.14.0 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.14.0-py3-none-any.whl.metadata (20 kB)
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.13.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting polib (from semantic-link-labs)
#   Downloading polib-1.2.0-py2.py3-none-any.whl.metadata (15 kB)
# Collecting jsonpath_ng (from semantic-link-labs)
#   Downloading jsonpath_ng-1.8.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: clr_loader>=0.2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.5)
# Collecting fabric-analytics-sdk<1.0.0,>=0.0.3 (from semantic-link-sempy>=0.14.0->semantic-link-labs)
#   Downloading fabric_analytics_sdk-0.0.3.post1-py3-none-any.whl.metadata (14 kB)
# Collecting fabric-analytics-notebook-plugin<1.0.0,>=0.0.3 (from semantic-link-sempy>=0.14.0->semantic-link-labs)
#   Downloading fabric_analytics_notebook_plugin-0.0.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (0.20.1)
# Requirement already satisfied: azure-storage-blob>=12.18.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (12.22.0)
# Requirement already satisfied: azure-core>=1.29.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2024.9.1)
# Collecting azure-keyvault-secrets>=4.7.0 (from semantic-link-sempy>=0.14.0->semantic-link-labs)
#   Downloading azure_keyvault_secrets-4.10.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: azure-storage-file-datalake>=12.12.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (12.16.0)
# Requirement already satisfied: ipywidgets>=8.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.1.2)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (14.0.2)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit_learn<1.8.0,>=1.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (1.2.2)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (4.65.0)
# Requirement already satisfied: rich>=13.3.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (13.3.5)
# Requirement already satisfied: regex>=2023.8.8 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.10.3)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.1.4)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pyspark>=3.4.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.5.1.5.4.20240407)
# Requirement already satisfied: requests>=2.31.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (2.31.0)
# Requirement already satisfied: aiohttp>=3.8.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (3.9.3)
# Requirement already satisfied: IPython>=8.14.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.20.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from semantic-link-sempy>=0.14.0->semantic-link-labs) (8.2.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from aiohttp>=3.8.6->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.9.3)
# Requirement already satisfied: isodate>=0.6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.6.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.9.0)
# Requirement already satisfied: cryptography>=2.1.4 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-storage-blob>=12.18.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (42.0.2)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from clr_loader>=0.2.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.9.0)
# Requirement already satisfied: azure-identity in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.15.0)
# Requirement already satisfied: synapseml-utils in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.1.6.post2)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.15.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.8.0)
# Requirement already satisfied: comm>=0.1.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from ipywidgets>=8.0.7->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.0.10)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pyspark>=3.4.1->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from requests>=2.31.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2024.2.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from rich>=13.3.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from scikit_learn<1.8.0,>=1.2.2->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.2.0)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from cffi>=1.13->clr_loader>=0.2.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.21)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from isodate>=0.6.1->azure-keyvault-secrets>=4.7.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from jedi>=0.16->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=13.3.5->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from pexpect>4.3->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.5)
# Collecting azure-core>=1.29.4 (from semantic-link-sempy>=0.14.0->semantic-link-labs)
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: msal<2.0.0,>=1.24.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.25.0)
# Requirement already satisfied: msal-extensions<2.0.0,>=0.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.0.0)
# Requirement already satisfied: executing in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.8.3)
# Requirement already satisfied: asttokens in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.0.5)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from stack-data->IPython>=8.14.0->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.2.2)
# Requirement already satisfied: fluent-logger in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from synapseml-utils->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.10.0)
# Requirement already satisfied: gson in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from synapseml-utils->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (0.0.4)
# Requirement already satisfied: portalocker<3,>=1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from msal-extensions<2.0.0,>=0.3.0->azure-identity->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (2.3.0)
# Requirement already satisfied: msgpack>1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.11/site-packages (from fluent-logger->synapseml-utils->fabric-analytics-notebook-plugin<1.0.0,>=0.0.3->semantic-link-sempy>=0.14.0->semantic-link-labs) (1.0.3)
# Downloading semantic_link_labs-0.14.0-py3-none-any.whl (868 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.5/868.5 kB 24.5 MB/s eta 0:00:0000:01
# Downloading semantic_link_sempy-0.14.0-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 47.9 MB/s eta 0:00:0000:0100:01
# Downloading anytree-2.13.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 13.8 MB/s eta 0:00:00
# Downloading jsonpath_ng-1.8.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 20.9 MB/s eta 0:00:00
# Downloading polib-1.2.0-py2.py3-none-any.whl (20 kB)
# Downloading azure_keyvault_secrets-4.10.0-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 39.4 MB/s eta 0:00:00
# Downloading fabric_analytics_notebook_plugin-0.0.3-py3-none-any.whl (24 kB)
# Downloading fabric_analytics_sdk-0.0.3.post1-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 10.3 MB/s eta 0:00:00
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.3/218.3 kB 57.2 MB/s eta 0:00:00
# Installing collected packages: polib, jsonpath_ng, anytree, azure-core, azure-keyvault-secrets, fabric-analytics-sdk, fabric-analytics-notebook-plugin, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: azure-core
#     Found existing installation: azure-core 2024.9.1
#     Uninstalling azure-core-2024.9.1:
#       Successfully uninstalled azure-core-2024.9.1
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.11.0
#     Uninstalling semantic-link-sempy-0.11.0:
#       Successfully uninstalled semantic-link-sempy-0.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fsspec-wrapper 0.1.15 requires PyJWT>=2.6.0, but you have pyjwt 2.4.0 which is incompatible.
# Successfully installed anytree-2.13.0 azure-core-1.30.2 azure-keyvault-secrets-4.10.0 fabric-analytics-notebook-plugin-0.0.3 fabric-analytics-sdk-0.0.3.post1 jsonpath_ng-1.8.0 polib-1.2.0 semantic-link-labs-0.14.0 semantic-link-sempy-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Notebook parameters

# %%
# Specify workspaces to ignore in this part of the process which collects metadata about your Fabric environment. 
# Either use exact workspace names or prefix or suffix with % as wildcard 
# This is useful when you have have many workspaces which don't need to be recovered 
# for businesss continuity purposes and collecting required metadata would take an unecessary amount of time 
# e.g. to ignore any workspaces suffixed with DEV or TEST use ['%DEV','%TEST%'] 

# These list parameters need to be in the format of ['string1','string2',...'stringN']. Use [] for an empty list.

# Specify an exact list of workspaces to ignore e.g. p_ws_ignore_list = ['Microsoft Fabric Capacity Metrics 26/02/2024 16:15:42','AdminInsights']
p_ws_ignore_list = [] 
# Specify a list with wildcards using % e.g. to ignore anything with _DEV and _TEST as a suffix p_ws_ignore_like_list = ['%_DEV%','%_TEST%']  
p_ws_ignore_like_list = [] #['%_DEV%','%_TEST%','%CLONE%']  
# Optionally specify an exact list of workspaces to recover
p_list_of_workspaces_to_recover = ['W1','W2'] #['Prod1','Prod2'] #specify exact workspaces

# Boolean parameter to specify verbose informational messages. 
# Only set to True if additional logging information required, otherwise notebook may generate significant (print) messages.
p_logging_verbose = False
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 6, Finished, Available, Finished, False)

# %% [markdown]
# ##### Check for default lakehouse

# %%
if (notebookutils.runtime.context['defaultLakehouseId']==None):
    displayHTML('<div style="display: flex; align-items: flex-end;"><img style="float: left; margin-right: 10px;" src="https://github.com/hurtn/images/blob/main/stop.png?raw=true" width="50"><span><h4>Please set a default lakehouse before proceeding</span><img style="float: right; margin-left: 10px;" src="https://github.com/hurtn/images/blob/main/stop.png?raw=true" width="50"></div>')
    print('\n')
    raise noDefaultLakehouseException('No default lakehouse found. Please add a lakehouse to this notebook.')
else: 
    print('Default lakehouse is set to '+ notebookutils.runtime.context['defaultLakehouseName'] + '('+ notebookutils.runtime.context['defaultLakehouseId'] + ')')
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 7, Finished, Available, Finished, False)
# Default lakehouse is set to LH_BCDR(a4a353d1-b396-401f-b8e7-f0ebfce81fa9)

# %% [markdown]
# ##### Store metadata of Capacities, Workspaces and Items

# %%
print('Gathering recovery metadata...')
saveCapacityMeta()
saveWorkspaceMeta()
saveItemMeta(verbose_logging=p_logging_verbose, ws_ignore_list=p_ws_ignore_list,ws_ignore_like_list=p_ws_ignore_like_list,list_of_workspaces_to_recover=p_list_of_workspaces_to_recover)
saveReportMeta(verbose_logging=p_logging_verbose,only_secondary=False,ws_ignore_list=p_ws_ignore_list,ws_ignore_like_list=p_ws_ignore_like_list)
print('Done')
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 8, Finished, Available, Finished, False)
# Gathering recovery metadata...
# 4 records saved to the capacities table.
# 55 records saved to the workspaces table.
# 55 records saved to the workspaces table.
# {'value': [{'id': '7bfe5249-7bbb-42a5-92ef-aa60656f06b8', 'type': 'Report', 'displayName': 'Product Profitability', 'description': '', 'workspaceId': 'b11cf9d8-5334-46d7-9159-9145c76f3ef1'}, {'id': '68017d30-7b3b-460d-9ad3-d75c6c03c9f6', 'type': 'SemanticModel', 'displayName': 'SemanticModel1', 'description': '', 'workspaceId': 'b11cf9d8-5334-46d7-9159-9145c76f3ef1'}, {'id': '2ed711de-845d-4c0a-9a5b-79a48b24480f', 'type': 'SQLEndpoint', 'displayName': 'Lakehouse1', 'description': '', 'workspaceId': 'b11cf9d8-5334-46d7-9159-9145c76f3ef1'}, {'id': 'a2aea914-dbb2-4f02-83d9-75e8ef0972fd', 'type': 'Warehouse', 'displayName': 'Warehouse1', 'description': '', 'workspaceId': 'b11cf9d8-5334-46d7-9159-9145c76f3ef1'}, {'id': '51faae96-512b-49c3-a83f-ee686b55cdb5', 'type': 'Lakehouse', 'displayName': 'Lakehouse1', 'description': '', 'workspaceId': 'b11cf9d8-5334-46d7-9159-9145c76f3ef1'}]}
# {'value': [{'id': 'e2b08043-a4bc-4900-9f10-62e7b776869a', 'type': 'Report', 'displayName': 'Passenger Trends', 'description': '', 'workspaceId': '24229fbf-ab93-4a2d-b906-0d08c3d1917b'}, {'id': '4699b32d-5ae7-4ea0-a675-09b9370414a2', 'type': 'SemanticModel', 'displayName': 'SemanticModel2', 'description': '', 'workspaceId': '24229fbf-ab93-4a2d-b906-0d08c3d1917b'}, {'id': '9b3135f7-1c64-439d-8f5e-fe44915dcebc', 'type': 'SQLEndpoint', 'displayName': 'Lakehouse2', 'description': '', 'workspaceId': '24229fbf-ab93-4a2d-b906-0d08c3d1917b'}, {'id': '2abacd66-0abc-4113-b800-de09c40e6a9d', 'type': 'Warehouse', 'displayName': 'Warehouse2', 'description': '', 'workspaceId': '24229fbf-ab93-4a2d-b906-0d08c3d1917b'}, {'id': '01aac1fc-96d4-418a-b91c-a6fcfc7a9e2d', 'type': 'Lakehouse', 'displayName': 'Lakehouse2', 'description': '', 'workspaceId': '24229fbf-ab93-4a2d-b906-0d08c3d1917b'}]}
# 10 records saved to the items table.
# 57 records saved to the reports table.
# Done

# %% [markdown]
# ##### Save Workspace Git Connection Details

# %%
from pyspark.sql.functions import lit

table_name = 'gitconnections'
spark.sql("Drop table if exists "+ table_name)
wsgitconnsql  ="SELECT distinct ID,Type,Name FROM workspaces where Type!='AdminInsights' and Name not like 'Microsoft Fabric Capacity Metrics%'"
if len(p_ws_ignore_like_list)>0:
    for notlike in p_ws_ignore_like_list:
        wsgitconnsql  = wsgitconnsql + " and name not like '" + notlike + "'"
if len(p_ws_ignore_list)>0:
    wsgitconnsql  = wsgitconnsql + " and name not in ('" + "', '".join(p_ws_ignore_list)+ "') "
if len(p_list_of_workspaces_to_recover)>0:
  wsgitconnsql = wsgitconnsql+" and Name in ('" +  "', '".join(p_list_of_workspaces_to_recover)+ "') "

#print(wsgitconnsql)


dfwks = spark.sql(wsgitconnsql).collect()
print("Retreiving Git details for any connected workspaces. This may take a few minutes...")
for idx,i in enumerate(dfwks):
    if i['Type'] == 'Workspace':
        url = "v1/workspaces/" + i['ID'] + "/git/connection"
        # url = "v1/admin/workspaces/discoverGitConnections"
        try:
            if p_logging_verbose:
                print("Storing git details for workspace "+i['Name']+" ("+i['ID']+')...')
            response = client.get(url)

            print(response.json())

            gitProviderDetailsJSON = response.json()['gitProviderDetails']
            gitConnectionStateJSON = response.json()['gitConnectionState']
            gitSyncDetailsJSON = response.json()['gitSyncDetails']

             # extract fields from gitProviderDetails
            repository_name = gitProviderDetailsJSON.get('repositoryName')
            git_provider_type = gitProviderDetailsJSON.get('gitProviderType')
            owner_name = gitProviderDetailsJSON.get('ownerName')
            branch_name = gitProviderDetailsJSON.get('branchName')
            directory_name = gitProviderDetailsJSON.get('directoryName')
            
            df = spark.createDataFrame([i['ID']],"string").toDF("Workspace_ID")
            
            df = (
                df.withColumn("Workspace_Name", lit(i['Name']))
                  .withColumn("gitConnectionState", lit(gitConnectionStateJSON))
                  .withColumn("repositoryName", lit(repository_name))
                  .withColumn("gitProviderType", lit(git_provider_type))
                  .withColumn("ownerName", lit(owner_name))
                  .withColumn("branchName", lit(branch_name))
                  .withColumn("directoryName", lit(directory_name))
                  .withColumn("gitProviderDetails", lit(json.dumps(gitProviderDetailsJSON)))
                  .withColumn("gitSyncDetails", lit(json.dumps(gitSyncDetailsJSON)))
            )

            if idx == 0:
                dfall = df
            else:
                dfall= dfall.union(df)
        except Exception as error:
            errmsg =  "Couldn't get git connection status for workspace " + i['Name'] + "("+ i['ID'] + ")."
            errmsg = errmsg + "Error: "+str(error)
            print(str(errmsg))

dfall.withColumn("metaTimestamp",current_timestamp()).write.mode('overwrite').option("mergeSchema", "true").saveAsTable(table_name)
print('Done')
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 9, Finished, Available, Finished, False)
# Retreiving Git details for any connected workspaces. This may take a few minutes...
# {'gitProviderDetails': {'ownerName': 'iamjenetzler', 'customDomainName': None, 'gitProviderType': 'GitHub', 'repositoryName': 'FabricBCDRDemo-W1', 'branchName': 'dev', 'directoryName': '/'}, 'gitSyncDetails': {'head': '9eef2fccbd40d7f3b9f75adef3b9d6fcc6c63341', 'lastSyncTime': '2026-03-17T17:00:18.813'}, 'gitConnectionState': 'ConnectedAndInitialized'}
# {'gitProviderDetails': {'ownerName': 'iamjenetzler', 'customDomainName': None, 'gitProviderType': 'GitHub', 'repositoryName': 'FabricBCDRDemo-W2', 'branchName': 'dev', 'directoryName': '/'}, 'gitSyncDetails': {'head': 'd99dae1a93f1616a71711dcd8e28c95db94bfc34', 'lastSyncTime': '2026-03-17T17:01:25.987'}, 'gitConnectionState': 'ConnectedAndInitialized'}
# Done

# %%
df = spark.sql("SELECT * FROM gitconnections LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, cd72335a-98fd-46bd-933e-338678927355)

# %% [markdown]
# ##### Save Workspace Role Assignments
#
# Using workspace APIs therefore requires permissions to access each workspace. If run as a Fabric Admin, use the cell below.

# %%
# iterate through workspaces and store role assignments in a list
import ast
all_role_data = []
table_name = 'wsroleassignments'

spark.sql("Drop table if exists "+ table_name)

rolesql = "SELECT distinct ID,Type,Name FROM workspaces where Type!='AdminInsights'"

if len(p_ws_ignore_like_list)>0:
    for notlike in p_ws_ignore_like_list:
        rolesql  = rolesql + " and name not like '" + notlike + "'"
if len(p_ws_ignore_list)>0:
    rolesql  = rolesql + " and name not in ('" + "', '".join(p_ws_ignore_list)+ "') "
if len(p_list_of_workspaces_to_recover)>0:
  rolesql = rolesql+" and Name in ('" +  "', '".join(p_list_of_workspaces_to_recover)+ "') "


print("Retreiving workspace role assignments...")

roledf = spark.sql(rolesql).collect()
for idx,i in enumerate(roledf):
    if i['Type'] == 'Workspace':
        url = "/v1/workspaces/" +i['ID'] + "/roleAssignments"
        try:
            if p_logging_verbose:
                print('Retreiving roles asignments for workspace '+ i['Name'] + '...')
            raresponse = client.get(url)
            roleassignments  =  raresponse.json()['value']
            for roleassignment in  roleassignments:
                roleassignment['workspaceName']=i['Name']
                roleassignment['workspaceId']=i['ID']
            #print(roleassignments)
            all_role_data.extend(roleassignments)
            
        except Exception as error:
            errmsg =  "Couldn't retreive role assignments for workspace " + i['Name'] + "("+ i['ID'] + "). Error: "+str(error)
            print(str(errmsg))

if all_role_data is not None and len(all_role_data)>0:
    roleassignmentdf = spark.read.json(sc.parallelize(all_role_data)) \
        .withColumn('principalId',col('principal')['id']) \
        .withColumn('displayName',col('principal')['displayName']) \
        .withColumn('principalType',col('principal')['type']) \
        .withColumn('userPrincipalName',col('principal')['userDetails']['userPrincipalName']) \
        .withColumn('workspaceId',col('workspaceId')) \
        .withColumn('workspaceName',col('workspaceName')) \
        .drop('principal')
    #display(roleassignmentdf)
    print(saveTable(roleassignmentdf,'wsroleassignments') ) 
else:
    print('No role data found.')
# Out:
# StatementMeta(, c5514911-8e1d-4377-acd2-4b188248397d, 11, Finished, Available, Finished, False)
# Retreiving workspace role assignments...
# 2 records saved to the wsroleassignments table.

# %% [markdown]
# ##### Save Workspace Role Assignments - Using Admin APIs

# %%
# iterate through workspaces and store role assignments in a list
import ast
all_role_data = []
table_name = 'wsroleassignments'

spark.sql("Drop table if exists "+ table_name)

rolesql = "SELECT distinct ID,Type,Name FROM workspaces where Type!='AdminInsights'"

if len(p_ws_ignore_like_list)>0:
    for notlike in p_ws_ignore_like_list:
        rolesql  = rolesql + " and name not like '" + notlike + "'"
if len(p_ws_ignore_list)>0:
    rolesql  = rolesql + " and name not in ('" + "', '".join(p_ws_ignore_list)+ "') "

print("Retreiving workspace role assignments...")

roledf = spark.sql(rolesql).collect()
for idx,i in enumerate(roledf):
    if i['Type'] == 'Workspace':
        #url = "/v1/workspaces/" +i['ID'] + "/roleAssignments"
        url = f"/v1.0/myorg/admin/groups/{i['ID']}/users"
        try:
            if p_logging_verbose:
                print('Retreiving roles asignments for workspace '+ i['Name'] + '...')
            raresponse = pbiclient.get(url)
            roleassignments  =  raresponse.json()['value']
            for roleassignment in  roleassignments:
                roleassignment['workspaceName']=i['Name']
                roleassignment['workspaceId']=i['ID']
            #print(roleassignments)
            all_role_data.extend(roleassignments)
            
        except Exception as error:
            errmsg =  "Couldn't retreive role assignments for workspace " + i['Name'] + "("+ i['ID'] + "). Error: "+str(error)
            print(str(errmsg))

if all_role_data is not None and len(all_role_data)>0:
        #.withColumn('principalId',col('graphId')) \
        #.withColumn('displayName',col('principal')['displayName']) \
        #.withColumn('principalType',col('principalType')) \
        #.withColumn('userPrincipalName',col('displayName')) \

    roleassignmentdf = spark.read.json(sc.parallelize(all_role_data)) \
        .withColumn('workspaceId',col('workspaceId')) \
        .withColumn('workspaceName',col('workspaceName')) 
#        .drop('principal')
    #display(roleassignmentdf)
    print(saveTable(roleassignmentdf,'wsroleassignments') ) 
else:
    print('No role data found.')

# %% [markdown]
# ##### Complete.
#
# Now proceed to Stage 3 in the associated accelerator documentation.
